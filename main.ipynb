# %%
from sklearn.datasets import load_breast_cancer
import numpy as np 


df = load_breast_cancer()
x = df.data
y = df.target

# %%
x = np.array(x)
y = np.array(y)

# %%
x
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %% [markdown]
# Test and Train

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Calculator metrics def

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

def caluculator(y_train , y_test, y_pred_train, y_pred_test ): 

    acc_train = accuracy_score(y_true=y_train, y_pred=y_pred_train)
    acc_test = accuracy_score(y_true=y_test, y_pred=y_pred_test)

    precision = precision_score(y_true=y_test, y_pred=y_pred_test)

    recall = recall_score(y_true=y_test, y_pred=y_pred_test)

    print( 'acc_train = ' , acc_train)
    print( 'test = ' , acc_test)
    print( 'precision = ' , precision)
    print( 'recall = ' , recall)

    return acc_train, acc_test, precision, recall

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

gnb.fit(X_train , Y_train)
# Out:
# GaussianNB()

# %%
y_pred_train = gnb.predict(X_train)
y_pred_test = gnb.predict(X_test)

# %%
acc_train_gnb, acc_test_gnb, precision_gnb, recall_gnb = caluculator(Y_train, Y_test, y_pred_train, y_pred_test)
# Out:
# acc_train =  0.9447236180904522
# test =  0.9298245614035088
# precision =  0.9469026548672567
# recall =  0.9469026548672567

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_pred_train = knn.predict(X_train)
knn_pred_test = knn.predict(X_test)

# %%
acc_train_knn, acc_test_knn, precision_knn, recall_knn = caluculator(Y_train, Y_test, knn_pred_train, knn_pred_test)
# Out:
# acc_train =  0.9798994974874372
# test =  0.9707602339181286
# precision =  0.9655172413793104
# recall =  0.9911504424778761

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt  = DecisionTreeClassifier(max_depth=30 , min_samples_split=5)
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=30, min_samples_split=5)

# %%
dt_pred_train = dt.predict(X_train)
dt_pred_test = dt.predict(X_test)

# %%
acc_train_dt , acc_test_dt, precision_dt, recall_dt = caluculator(Y_train, Y_test, dt_pred_train, dt_pred_test)
# Out:
# acc_train =  0.9874371859296482
# test =  0.935672514619883
# precision =  0.9553571428571429
# recall =  0.9469026548672567

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, min_samples_split=5)
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(min_samples_split=5)

# %%
rf_pred_train = rf.predict(X_train)
rf_pred_test = rf.predict(X_test)

# %%
acc_train_rf, acc_test_rf, precision_rf, recall_rf = caluculator(Y_train, Y_test, rf_pred_train, rf_pred_test)
# Out:
# acc_train =  1.0
# test =  0.9590643274853801
# precision =  0.9649122807017544
# recall =  0.9734513274336283

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC

svc = SVC(kernel='rbf' , gamma='auto')
svc.fit(X_train, Y_train)
# Out:
# SVC(gamma='auto')

# %%
svc_pred_train = svc.predict(X_train)
svc_pred_test = svc.predict(X_test)

# %%
acc_train_svc, acc_test_svc, precision_svc, recall_svc = caluculator(Y_train, Y_test, svc_pred_train, svc_pred_test)
# Out:
# acc_train =  0.9447236180904522
# test =  0.9590643274853801
# precision =  0.9416666666666667
# recall =  1.0

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
lr_pred_train = lr.predict(X_train)
lr_pred_test = lr.predict(X_test)

# %%
# acc_train_lr, acc_test_lr, precision_lr, recall_lr = caluculator(Y_train, Y_test, lr_pred_train, lr_pred_test)

# %% [markdown]
# ANN (Artificial Neural Network)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=512, activation='identity', solver='adam')
mlp.fit(X_train, Y_train)
# Out:
# d:\machin learning\ML Projects\breast cancer detection\breast_cancer\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(activation='identity', hidden_layer_sizes=512)

# %%
mlp_prd_train = mlp.predict(X_train)
mlp_prd_test = mlp.predict(X_test)

# %%
acc_train_mlp, acc_test_mlp, precision_mlp, recall_mlp = caluculator(Y_train, Y_test, mlp_prd_train, mlp_prd_test)
# Out:
# acc_train =  0.9849246231155779
# test =  0.9707602339181286
# precision =  0.9655172413793104
# recall =  0.9911504424778761
